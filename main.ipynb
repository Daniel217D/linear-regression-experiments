# %% [markdown]
# # Проект анализа данных (шаблон)

# %%
# Установка зависимостей
# !pip install -r requirements.txt

# %% [markdown]
# ## 1. Настройка и загрузка данных
#
# Настройте окружение, подключитесь к базе данных и выполните запрос на извлечение данных.

# %%
from dotenv import load_dotenv
import os

import pandas as pd
import numpy as np

import phik
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mpl.rcParams['figure.constrained_layout.use'] = True

# %%
load_dotenv(dotenv_path='.env')
SOME_VARIABLE=os.getenv('SOME_VARIABLE')

# %%
df = ...  # загрузка из файла, url, БД и т.д.

# %%
df.head()

# %% [markdown]
# ### 1.1 Обзор данных
#
# Проверьте размер, типы столбцов и пропущенные значения.

# %%
df.shape

# %%
df.info()

# %%
df.isna().sum()
